# %% [markdown]
# # **Machine Learning Modelling for Fraud Detection**
#
# **Notebook Outline:**
#
# - Background to Fraud Detection:
#     - Techniques
#     - Modellings
#     - Intepretaton
#     - Visualization
# - Load and View different Fraud datasets
# - Perform Data Integration (if requireD) and Feature Engineering
# - Offline Modelling:
#     - Linear Classifier
#     - Tree-Based Classifier
#     - Cluster BAsed Clasifier
#     - Deep Learning Based Classifer
#
# **Datasets:**
# - Traditional Transaction Data for Fraud Detection: https://www.kaggle.com/isaikumar/creditcardfraud/data
#
# - More Complex Use case, Chargeback Frauds: https://www.kaggle.com/dmirandaalves/predict-chargeback-frauds-payment/kernels

# %% [markdown]
# ## Housekeeping: Imports and Configuration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import logistic

import src.datautils.DataWrangler as dw
import src.datautils.ModelWrangler as mw

# %% [markdown]
# ## Section 1: Traditional Credit Card Fraud Dataset
#
# In the following example we're to be looking at a traditional dataset which contains timestamp records of credit card transactions, with a given number of features, and a labelled class which states if it is a fraudulant transaction, or not.
#
# The example we will work with does not require extensive feature engineering to kick things off, however, when dealing with real-world use cases, typically the available features, of the type of data which is available may not be so clean.
#
# It is important to also consider the context of timeseires data, with respects to the underlying trend and seasonality components. Take the example of a fraud detection system which has been trained on data collected in July, and then model prediction is performed on data captured in December, due to the holiday period, the propensity to spend may be greater, thus the model may wrongly interpret the volume of transactions as a indicator foor a fraudlant transaction

# %% [markdown]
# ## Load Data

# %%
wrangler = dw.DataWrangler()
# Out:
# Data Wrangling Tooling

# %%
df= wrangler.load_data_to_dataframe('data/creditcard.csv')

# %%
wrangler.describe_dataframe(df, stats=True, histgraphs=True, scattergraph=False)
# Out:
# **Basic Dataframe Details**
# ---
# Data Shape:
# Total Records 284807
# Total Columns 31
# Column Names ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class']
# ---
# Descriptive Stats:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.537294e-16  7.959909e-16  5.367590e-16  4.458112e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.453003e-15  1.699104e-15 -3.660161e-16 -1.206049e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]
# Column: Time. Skew/Kurt: -0.0355676180063216 / -1.2935300508989838
# Column: V1. Skew/Kurt: -3.280667302756041 / 32.48667948607062
# Column: V2. Skew/Kurt: -4.624865573285336 / 95.7731059638466
# Column: V3. Skew/Kurt: -2.240155440240421 / 26.619550806364018
# Column: V4. Skew/Kurt: 0.676292097985747 / 2.6354549146787125
# Column: V5. Skew/Kurt: -2.4259014959520533 / 206.90455995692014
# Column: V6. Skew/Kurt: 1.826580664998085 / 42.64249396253933
# Column: V7. Skew/Kurt: 2.553907417429514 / 405.6074170083754
# Column: V8. Skew/Kurt: -8.521944194777976 / 220.58697362515312
# Column: V9. Skew/Kurt: 0.5546797719063509 / 3.731310614141207
# Column: V10. Skew/Kurt: 1.1871405899625276 / 31.98823877949119
# Column: V11. Skew/Kurt: 0.35650585548882024 / 1.6339212577978683
# Column: V12. Skew/Kurt: -2.2784009354106174 / 20.241869662225433
# Column: V13. Skew/Kurt: 0.06523345790658323 / 0.19529978783246627
# Column: V14. Skew/Kurt: -1.9951758402683304 / 23.87946184493846
# Column: V15. Skew/Kurt: -0.308422982135924 / 0.28476908376068266
# Column: V16. Skew/Kurt: -1.100966276051066 / 10.419131320644887
# Column: V17. Skew/Kurt: -3.844914473870619 / 94.79971910397433
# Column: V18. Skew/Kurt: -0.25988026809430603 / 2.5783408337335967
# Column: V19. Skew/Kurt: 0.10919175998147107 / 1.7249697812275109
# Column: V20. Skew/Kurt: -2.037155299081398 / 271.0161129504152
# Column: V21. Skew/Kurt: 3.5929911930778453 / 207.28704035333402
# Column: V22. Skew/Kurt: -0.21325762284328822 / 2.8329665163717817
# Column: V23. Skew/Kurt: -5.875140340106818 / 440.0886586749539
# Column: V24. Skew/Kurt: -0.5524993011673045 / 0.6188707999933452
# Column: V25. Skew/Kurt: -0.41579259031563515 / 4.290412283119672
# Column: V26. Skew/Kurt: 0.5766926172084218 / 0.919005770879612
# Column: V27. Skew/Kurt: -1.170208942432713 / 244.98924056630818
# Column: V28. Skew/Kurt: 11.192091192212809 / 933.3975020960183
# Column: Amount. Skew/Kurt: 16.977724453761024 / 845.0926455465277
# Column: Class. Skew/Kurt: 23.99757931064749 / 573.887842782971

# %% [markdown]
# ### Feature Engineering
#
# In this section, we can exqmine the linearity of the features, and understand their dependency between each other,
#
# The purpose of feature engineering is to be able to reduce or create new features to improve the performance of the model, depending on the type of mdeolling task to be acheived.
#
# When performing feature engineering, it is typically performed in combination with modelling, rather than in isolation from each other. Taking this into consideration, it's important to consider feature engineering as an iterative, continous process which requires re-inspection over the lifetime of a models development and production cycle,.

# %% [markdown]
# #### Feature Correlation Analysis

# %%
wrangler.correlation_analysis(df)

# correlation_analysis(df)
# Out:
# No Co-Linear Featurs Found, However there may be correlated features depending on their poly transform
# []

# %% [markdown]
# ### More Feature Engineering to be performed.

# %%
def model_features(df, target_col_str='Class'):
    
    y = df[target_col_str].values
    X = df.drop(target_col_str, axis=1).values
    
    logit_model = sm.Logit(y,X)
    cdf = logit_model.cdf(X)
    print(cdf.shape)
    print(cdf[32][29])

#     cdf = pd.Series(cdf[31])
    
    result = logit_model.fit()
    
#     cdf.hist()
    print(result.summary())
#     plt.show()
    

model_features(df)
# Out:
# (284807, 30)
# 0.9978497100922109
# Optimization terminated successfully.
#          Current function value: 0.009803
#          Iterations 12
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:               284807
# Model:                          Logit   Df Residuals:                   284777
# Method:                           MLE   Df Model:                           29
# Date:                Wed, 11 Dec 2019   Pseudo R-squ.:                  0.2290
# Time:                        21:22:10   Log-Likelihood:                -2792.0
# converged:                       True   LL-Null:                       -3621.2
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1         -9.112e-05   1.63e-06    -55.892      0.000   -9.43e-05   -8.79e-05
# x2             0.5835      0.034     17.352      0.000       0.518       0.649
# x3            -1.3789      0.041    -33.988      0.000      -1.458      -1.299
# x4            -1.5799      0.034    -45.877      0.000      -1.647      -1.512
# x5             0.3613      0.030     11.857      0.000       0.302       0.421
# x6            -0.8822      0.058    -15.203      0.000      -0.996      -0.768
# x7             0.4379      0.044     10.023      0.000       0.352       0.523
# x8             1.4822      0.064     23.203      0.000       1.357       1.607
# x9            -0.5200      0.023    -22.248      0.000      -0.566      -0.474
# x10           -0.7556      0.053    -14.183      0.000      -0.860      -0.651
# x11           -0.9075      0.064    -14.202      0.000      -1.033      -0.782
# x12           -0.5670      0.041    -13.858      0.000      -0.647      -0.487
# x13           -0.0608      0.042     -1.449      0.147      -0.143       0.021
# x14           -0.4250      0.041    -10.398      0.000      -0.505      -0.345
# x15           -0.5469      0.038    -14.304      0.000      -0.622      -0.472
# x16           -0.9436      0.047    -19.923      0.000      -1.036      -0.851
# x17           -0.4942      0.051     -9.617      0.000      -0.595      -0.394
# x18           -0.5660      0.041    -13.954      0.000      -0.646      -0.487
# x19            0.4448      0.057      7.831      0.000       0.333       0.556
# x20           -0.3160      0.059     -5.378      0.000      -0.431      -0.201
# x21            2.3242      0.153     15.205      0.000       2.025       2.624
# x22            1.4482      0.061     23.577      0.000       1.328       1.569
# x23            0.8492      0.080     10.566      0.000       0.692       1.007
# x24            0.4615      0.113      4.098      0.000       0.241       0.682
# x25           -0.0691      0.067     -1.025      0.306      -0.201       0.063
# x26           -1.6482      0.089    -18.458      0.000      -1.823      -1.473
# x27            0.2996      0.086      3.465      0.001       0.130       0.469
# x28           -1.1597      0.135     -8.576      0.000      -1.425      -0.895
# x29            0.6275      0.108      5.815      0.000       0.416       0.839
# x30           -0.0217      0.001    -25.512      0.000      -0.023      -0.020
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.60 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.

# %% [markdown]
# ### Modelling
#
# Once we have performed some feature analysis and engineering, we can now move the modelling stages of the Data Science process.
#
# Before jumping into complex methods and modelling approaches, it is important to fiurst establish your baseline mode, which would be using a very simple approach first, and then work towards more complex models, and even, more complex combinations of classifiers in order to build a robust predictive model.
#
# The first step here will be to prepare our data, which involves converting our dataframes into matrices, and also (if being used in a supervised learning model), splitting the data into train and test (and if required), validate.
#
# Many times, the methodology of splitting data is extremely important in the training and validation of a model. Take a timeseries model, when performing modelling, one would to preserve the order of the data points, as the sequence is an important characteristic of a timeseires model (e.g. ARIMA).
#
# In a classification task, sampling techniques is also highly important, as if we are dealing with a imbalanced set of classes (e.g. 90% of the data points are for 1 class out of k), then if splitting the data without awaremess of the proportion of data points within a given class, we will affect the models capability to provide a suitable decision boundary / H(x). In these cases, we start to encounter forms of overfitting and underfitting.
#
# It is important to also consider how one can perform cross-validation on the data in order to reduce the chances of badly performing models.
#
# **Cross Validation**
# Cross-Validation is similar to train/test split, but it’s applied to more subsets. Meaning, the data is split into k subsets, and train on k-1 one of those subset. What we do is to hold the last subset for test. We’re able to do it for each of the subsets.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Modelling Data Preparation

# %%
modeller = mw.ModelWrangler()
# Out:
# Model Wrangler

# %%
model_data = modeller.prepare_test_train_data(df, isShuffle = True, 
                                              isStratify=True, isStringTarget=False, isScaler = True)
#                                              features = ['V1'])
# Out:
# Generating Training / Test Split
# Training X: 199364, y: 199364
# Test X: 85443, y: 85443

# %%
model_data_kfolds = modeller.prepare_kfold_test_train_data(df, isShuffle = True, isStratify=True)
# Out:
# Generating 5 KFold Training / Test Splits
# Training X: 227845, y: 227845
# Test X: 56962, y: 56962
# Training X: 227845, y: 227845
# Test X: 56962, y: 56962
# Training X: 227846, y: 227846
# Test X: 56961, y: 56961
# Training X: 227846, y: 227846
# Test X: 56961, y: 56961
# Training X: 227846, y: 227846
# Test X: 56961, y: 56961

# %% [markdown]
# ### Baseline Model: Logisitic Regression
#
# The baseline model will comprise of a simple Logisitic Regression Classifier without regularization, or data sampling.

# %%
model_logr = modeller.logR_model(model_data)
# Out:
# Accuracy of logistic regression classifier on test set: 1.00
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.00      0.00      0.00       148
#
#     accuracy                           1.00     85443
#    macro avg       0.50      0.50      0.50     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
modeller.roc_plot(model_data, model_logr)
# Out:
# No Skill: ROC AUC=0.500
# Logistic: ROC AUC=0.812
# /Users/tramine/opt/anaconda3/envs/gpu-tf/lib/python3.7/site-packages/sklearn/metrics/_ranking.py:549: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   y_true = (y_true == pos_label)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-19abfd51ec0b> in <module>
# ----> 1 modeller.roc_plot(model_data, model_logr)
#
# ~/Documents/Jupyter/Fraud Analysis/src/datautils/ModelWrangler.py in roc_plot(self, model_data, model)
#     159         print('Logistic: ROC AUC=%.3f' % (lr_auc))
#     160         # calculate roc curves
# --> 161         ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs, pos_label='True')
#     162         lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs, pos_label='True')
#     163         # plot the roc curve for the model
#
# ~/opt/anaconda3/envs/gpu-tf/lib/python3.7/site-packages/sklearn/metrics/_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     749     """
#     750     fps, tps, thresholds = _binary_clf_curve(
# --> 751         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight)
#     752
#     753     # Attempt to drop thresholds corresponding to points in between and
#
# ~/opt/anaconda3/envs/gpu-tf/lib/python3.7/site-packages/sklearn/metrics/_ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     552     desc_score_indices = np.argsort(y_score, kind="mergesort")[::-1]
#     553     y_score = y_score[desc_score_indices]
# --> 554     y_true = y_true[desc_score_indices]
#     555     if sample_weight is not None:
#     556         weight = sample_weight[desc_score_indices]
#
# TypeError: 'bool' object is not subscriptable

# %% [markdown]
# ### Tree-based Model: XGBoost

# %%
xgboost_mdl = modeller.xgboost_model(model_data)
# Out:
# Accuracy: 99.83%
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.00      0.00      0.00       148
#
#     accuracy                           1.00     85443
#    macro avg       0.50      0.50      0.50     85443
# weighted avg       1.00      1.00      1.00     85443
# /Users/tramine/opt/anaconda3/envs/gpu-tf/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
modeller.roc_plot(model_data, xgboost_mdl)
# Out:
# /Users/tramine/opt/anaconda3/envs/gpu-tf/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# No Skill: ROC AUC=0.500
# Logistic: ROC AUC=0.891

# %%
import tensorflow as tf
from imblearn.over_sampling import SMOTE, ADASYN
from imblearn.under_sampling import NearMiss
from imblearn.combine import SMOTEENN
from collections import Counter
from sklearn.metrics import classification_report
from imblearn.over_sampling import BorderlineSMOTE


class tf_logR_model:
    
    def __init__(self, data = None, 
                 learning_rate = 0.01, 
                 training_steps = 10000,
                 batch_size = 128,
                 display_step = 100):
        
        print('Neural Network Loading')
        
        
        self.model_data = data
        
        X_train, X_test, y_train, y_test = self.model_data

        self.num_classes = len(np.unique(y_train)) # total classes (0-9 digits).

        self.num_features = X_train.shape[1] # data features (img shape: 28*28).
        print('Classes {}, Features {}'.format(self.num_classes, self.num_features))
        
        # Training parameters.
       
        self.learning_rate =learning_rate
        self.training_steps = training_steps
        self.batch_size = batch_size
        self.display_step = display_step  
        
        # A random value generator to initialize weights.
        self.random_normal = tf.initializers.RandomNormal()
        
        # Stochastic gradient descent optimizer.
        self.optimizer = tf.optimizers.Adam(self.learning_rate)
        
        # Network parameters.
        self.n_hidden_1 = 126 # 1st layer number of neurons.
        self.n_hidden_2 = 256 # 2nd layer number of neurons.
        self.n_hidden_3 = 512 # 3rd layer number of neurons.


        self.weights = {
        'h1': tf.Variable(self.random_normal([self.num_features, self.n_hidden_1])),
        'h2': tf.Variable(self.random_normal([self.n_hidden_1, self.n_hidden_2])),
        'h3': tf.Variable(self.random_normal([self.n_hidden_2, self.n_hidden_3])),
        'out': tf.Variable(self.random_normal([self.n_hidden_3, self.num_classes]))
        }
        self.biases = {
        'b1': tf.Variable(tf.zeros([self.n_hidden_1])),
        'b2': tf.Variable(tf.zeros([self.n_hidden_2])),
        'b3': tf.Variable(tf.zeros([self.n_hidden_3])),
        'out': tf.Variable(tf.zeros([self.num_classes]))
        }
        

    # Create model.
    def neural_net(self, x):
        # Hidden fully connected layer with 128 neurons.
        layer_1 = tf.add(tf.matmul(x, self.weights['h1']), self.biases['b1'])
        # Apply sigmoid to layer_1 output for non-linearity.
        layer_1 = tf.nn.sigmoid(layer_1)

        # Hidden fully connected layer with 256 neurons.
        layer_2 = tf.add(tf.matmul(layer_1, self.weights['h2']), self.biases['b2'])
        # Apply sigmoid to layer_2 output for non-linearity.
        layer_2 = tf.nn.sigmoid(layer_2)

        # Hidden fully connected layer with 512 neurons.
        layer_3 = tf.add(tf.matmul(layer_2, self.weights['h3']), self.biases['b3'])
        # Apply sigmoid to layer_2 output for non-linearity.
        layer_3 = tf.nn.sigmoid(layer_3)

        # Output fully connected layer with a neuron for each class.
        out_layer = tf.matmul(layer_3, self.weights['out']) + self.biases['out']
        # Apply softmax to normalize the logits to a probability distribution.
        return tf.nn.softmax(out_layer)



    # Cross-Entropy loss function.
    def cross_entropy(self, y_pred, y_true):
        # Encode label to a one hot vector.
        y_true = tf.one_hot(y_true, depth=self.num_classes)
        # Clip prediction values to avoid log(0) error.
        y_pred = tf.clip_by_value(y_pred, 1e-9, 1.)
        # Compute cross-entropy.
        return tf.reduce_mean(-tf.reduce_sum(y_true * tf.math.log(y_pred)))

    # Accuracy metric.
    def accuracy(self, y_pred, y_true):
        # Predicted class is the index of highest score in prediction vector (i.e. argmax).
        correct_prediction = tf.equal(tf.argmax(y_pred, 1), tf.cast(y_true, tf.int64))
        return tf.reduce_mean(tf.cast(correct_prediction, tf.float32), axis=-1)

    def splt(self, y, class_a = 0, class_b = 1):
        zero = []
        one = []
        for x in y:
            if x == class_a:
                zero.append(0)
            else:
                one.append(1)

        print('Class {}: {} Class {}: {}'.format(class_a, len(zero), class_b, len(one)))

    def make_ds(self, features, labels):
        BUFFER_SIZE = 100000
        ds = tf.data.Dataset.from_tensor_slices((features, labels))#.cache()
        ds = ds.shuffle(BUFFER_SIZE).repeat()
        return ds

    def resample(self, model_data, class_weights):

        X_train, X_test, y_train, y_test = model_data
        y_train = list(y_train)
        X_train, X_test = np.array(X_train, np.float32), np.array(X_test, np.float32)
        self.splt(y_train)

        #split data by pos and neg features as we need to balance data
        pos_features = []
        neg_features = []
        pos_labels = []
        neg_labels = []

        for i in range(0,len(X_train)):
    #         print('y i; ',y_train[i])
            if y_train[i] is 0:
                neg_features.append(X_train[i])
                neg_labels.append(y_train[i])
            else:
                pos_features.append(X_train[i])
                pos_labels.append(y_train[i])

        pos_ds = self.make_ds(pos_features, pos_labels)
        neg_ds = self.make_ds(neg_features, neg_labels)
        if class_weights:
            resampled_ds = tf.data.experimental.sample_from_datasets([pos_ds, neg_ds], weights=class_weights)
            train_data = resampled_ds.batch(self.batch_size).prefetch(2)

        else:
            train_data = tf.data.Dataset.from_tensor_slices((X_train, y_train))
            train_data = train_data.repeat().shuffle(X_train.shape[0]).batch(self.batch_size)
            
        return train_data

    
    # Optimization process. 
    def run_optimization(self, x, y):
        # Wrap computation inside a GradientTape for automatic differentiation.
        with tf.GradientTape() as g:
            pred = self.neural_net(x)
            loss = self.cross_entropy(pred, y)

        # Variables to update, i.e. trainable variables.
        trainable_variables = list(self.weights.values()) + list(self.biases.values())

        # Compute gradients.
        gradients = g.gradient(loss, trainable_variables)

        # Update W and b following gradients.
        self.optimizer.apply_gradients(zip(gradients, trainable_variables))

    
    
    def run_tf_model(self, class_weights):
        
        train_data = self.resample(self.model_data, class_weights = class_weights)

#         # Training parameters.

        # Run training for the given number of steps.
        for step, (batch_x, batch_y) in enumerate(train_data.take(self.training_steps), 1):
            # Run the optimization to update W and b values.
            self.run_optimization(batch_x, batch_y)

            if step % self.display_step == 0:
                
                self.splt(batch_y)

                pred = self.neural_net(batch_x)
                loss = self.cross_entropy(pred, batch_y)
                acc = self.accuracy(pred, batch_y)
                print("step: %i, loss: %f, accuracy: %f" % (step, loss, acc))

    # Test model on validation set.
    def predict(self, model_data, balance_classes=False):

        X_train, X_test, y_train, y_test = model_data
        y_test = list(y_test)

        if balance_classes:
            smote = SMOTE()

            X_test, y_test = smote.fit_resample(X_test, y_test)

        self.splt((y_test))

        X_test = np.array(X_test, np.float32)

        preds = self.neural_net(X_test)

        print("Test Accuracy: %f" % self.accuracy(preds, y_test))

        pred_lbls = tf.argmax(preds,1)

        return list(pred_lbls.numpy()), y_test

# %%
tf_model = tf_logR_model(data=model_data,  
                         training_steps = 1000,
                         batch_size = 5000)

tf_model.run_tf_model(class_weights=[0.5,0.5])
# Out:
# Neural Network Loading
# Classes 2, Features 30
# Class 0: 199020 Class 1: 344
# Class 0: 2531 Class 1: 2469
# step: 100, loss: 451.182922, accuracy: 0.959800
# Class 0: 2481 Class 1: 2519
# step: 200, loss: 115.939720, accuracy: 0.995000
# Class 0: 2523 Class 1: 2477
# step: 300, loss: 19.597984, accuracy: 0.999200
# Class 0: 2542 Class 1: 2458
# step: 400, loss: 28.710732, accuracy: 0.999000
# Class 0: 2486 Class 1: 2514
# step: 500, loss: 5.061870, accuracy: 0.999800
# Class 0: 2480 Class 1: 2520
# step: 600, loss: 6.215857, accuracy: 1.000000
# Class 0: 2516 Class 1: 2484
# step: 700, loss: 6.153893, accuracy: 0.999600
# Class 0: 2515 Class 1: 2485
# step: 800, loss: 3.763532, accuracy: 0.999600
# Class 0: 2496 Class 1: 2504
# step: 900, loss: 3.909825, accuracy: 0.999800
# Class 0: 2459 Class 1: 2541
# step: 1000, loss: 4.040263, accuracy: 1.000000

# %%
nn_preds, y_true = tf_model.predict(model_data, balance_classes=False)
# Out:
# Class 0: 85295 Class 1: 148
# Test Accuracy: 0.999204

# %%
print(classification_report(y_true, nn_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.76      0.79      0.77       148
#
#     accuracy                           1.00     85443
#    macro avg       0.88      0.90      0.89     85443
# weighted avg       1.00      1.00      1.00     85443
